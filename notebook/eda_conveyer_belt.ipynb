# %%
import sys
import os
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(PROJECT_ROOT)

from model.utils import (
    load_and_clean_data,
    show_summary,
    plot_feature_distributions,
    plot_feature_correlation_heatmap,
    plot_input_target_correlation_heatmap,
    plot_input_target_pairplot,
    plot_feature_boxplots,
    plot_target_distributions,
    plot_target_boxplots,
    get_device_name,
    append_suffix,
    DEVICE_TARGET_FEATURES,
    INPUT_FEATURES
)
INPUT_FEATURES = append_suffix(INPUT_FEATURES, "mean")
DEVICE = "conveyor_belt"
TARGET_FEATURES = DEVICE_TARGET_FEATURES[DEVICE]
DATA_DIR = "../Data/process/8#Belt Conveyer_merged.csv"
SAVE_PATH = f"../docs/images/{DEVICE}_plots/"
# Out:
# Logs are being stored in: /Users/adetsi/Desktop/capstone/capstone/model/src/preprocessing.log

# %%
INPUT_FEATURES = [
    'High-Frequency Acceleration_mean',
    'High-Frequency Acceleration_min',
    'High-Frequency Acceleration_max',
    'High-Frequency Acceleration_median',
    'High-Frequency Acceleration_std',
    'Low-Frequency Acceleration Z_mean',
    'Low-Frequency Acceleration Z_min',
    'Low-Frequency Acceleration Z_max',
    'Low-Frequency Acceleration Z_median',
    'Low-Frequency Acceleration Z_std',
    'Temperature_mean',
    'Temperature_min',
    'Temperature_max',
    'Temperature_median',
    'Temperature_std',
    'Vibration Velocity Z_mean',
    'Vibration Velocity Z_min',
    'Vibration Velocity Z_max',
    'Vibration Velocity Z_median',
    'Vibration Velocity Z_std'
]

# %%
df = load_and_clean_data(DATA_DIR)

# %%
show = ['datetime','High-Frequency Acceleration_mean','High-Frequency Acceleration_min','fit_condition','kurtosis_opt','rms_10_25khz']
df[show].head()
# Out:
#               datetime  High-Frequency Acceleration_mean  \
# 0  2025-04-01 00:20:00                          2.462857
# 1  2025-04-01 00:40:00                          2.438217
# 2  2025-04-01 01:20:00                          2.435225
# 3  2025-04-01 01:40:00                          2.447685
# 4  2025-04-01 02:20:00                          2.441172
#
#    High-Frequency Acceleration_min  fit_condition  kurtosis_opt  rms_10_25khz
# 0                          1.57066          88.27         85.67          98.0
# 1                          1.52645          85.31         85.62          98.0
# 2                          1.46135          84.47         85.55          98.0
# 3                          1.51597          88.77         84.67          98.0
# 4                          1.52165          88.94         85.95          98.0

# %%
show_summary(df)
# Out:
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 715 entries, 0 to 714
# Data columns (total 35 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   datetime                             715 non-null    object
#  1   High-Frequency Acceleration_mean     715 non-null    float64
#  2   High-Frequency Acceleration_min      715 non-null    float64
#  3   High-Frequency Acceleration_max      715 non-null    float64
#  4   High-Frequency Acceleration_median   715 non-null    float64
#  5   High-Frequency Acceleration_std      715 non-null    float64
#  6   Low-Frequency Acceleration Z_mean    715 non-null    float64
#  7   Low-Frequency Acceleration Z_min     715 non-null    float64
#  8   Low-Frequency Acceleration Z_max     715 non-null    float64
#  9   Low-Frequency Acceleration Z_median  715 non-null    float64
#  10  Low-Frequency Acceleration Z_std     715 non-null    float64
#  11  Temperature_mean                     715 non-null    float64
#  12  Temperature_min                      715 non-null    float64
#  13  Temperature_max                      715 non-null    float64
#  14  Temperature_median                   715 non-null    float64
#  15  Temperature_std                      715 non-null    float64
#  16  Vibration Velocity Z_mean            715 non-null    float64
#  17  Vibration Velocity Z_min             715 non-null    float64
#  18  Vibration Velocity Z_max             715 non-null    float64
#  19  Vibration Velocity Z_median          715 non-null    float64
#  20  Vibration Velocity Z_std             715 non-null    float64
#  21  location                             715 non-null    object
#  22  Device                               715 non-null    object
#  23  alignment_status                     715 non-null    float64
#  24  bearing_lubrication                  715 non-null    float64
#  25  crest_factor                         715 non-null    float64
#  26  electromagnetic_status               715 non-null    float64
#  27  fit_condition                        715 non-null    float64
#  28  kurtosis_opt                         715 non-null    float64
#  29  peak_value_opt                       715 non-null    float64
#  30  rms_10_25khz                         715 non-null    float64
#  31  rms_1_10khz                          715 non-null    float64
#  32  rotor_balance_status                 715 non-null    float64
#  33  rubbing_condition                    715 non-null    float64
#  34  velocity_rms                         715 non-null    float64
# dtypes: float64(32), object(3)
# memory usage: 195.6+ KB
# None
#
# Statistical Summary:
#        High-Frequency Acceleration_mean  High-Frequency Acceleration_min  \
# count                        715.000000                       715.000000
# mean                           2.320366                         1.501320
# std                            0.107521                         0.123826
# min                            1.825365                         0.039000
# 25%                            2.263811                         1.470710
# 50%                            2.324199                         1.522560
# 75%                            2.400221                         1.556340
# max                            2.547862                         1.702940
#
#        High-Frequency Acceleration_max  High-Frequency Acceleration_median  \
# count                       715.000000                          715.000000
# mean                          3.354875                            2.332738
# std                           0.390366                            0.187818
# min                           2.662220                            2.010520
# 25%                           3.109865                            2.186578
# 50%                           3.231230                            2.264695
# 75%                           3.582770                            2.485880
# max                           7.370280                            2.755975
#
#        High-Frequency Acceleration_std  Low-Frequency Acceleration Z_mean  \
# count                       715.000000                         715.000000
# mean                          0.506941                           2.072488
# std                           0.037506                           0.107069
# min                           0.413868                           1.627287
# 25%                           0.483403                           2.021259
# 50%                           0.506522                           2.085821
# 75%                           0.529902                           2.139133
# max                           0.909620                           2.379039
#
#        Low-Frequency Acceleration Z_min  Low-Frequency Acceleration Z_max  \
# count                        715.000000                        715.000000
# mean                           1.410500                          3.063061
# std                            0.123833                          0.443924
# min                            0.016090                          2.271960
# 25%                            1.374770                          2.710595
# 50%                            1.431120                          2.934670
# 75%                            1.467535                          3.423510
# max                            1.637260                          5.721360
#
#        Low-Frequency Acceleration Z_median  Low-Frequency Acceleration Z_std  \
# count                           715.000000                        715.000000
# mean                              2.071502                          0.391595
# std                               0.126194                          0.043275
# min                               1.754550                          0.323076
# 25%                               1.986765                          0.363487
# 50%                               2.078490                          0.383195
# 75%                               2.158955                          0.413244
# max                               2.501430                          0.792056
#
#        ...  crest_factor  electromagnetic_status  fit_condition  kurtosis_opt  \
# count  ...    715.000000                   715.0     715.000000    715.000000
# mean   ...     91.070951                    98.0      88.415259     86.325664
# std    ...      0.844172                     0.0       2.469648      0.821938
# min    ...     88.100000                    98.0      80.330000     82.880000
# 25%    ...     90.605000                    98.0      87.615000     86.055000
# 50%    ...     91.270000                    98.0      89.130000     86.590000
# 75%    ...     91.670000                    98.0      90.040000     86.880000
# max    ...     92.760000                    98.0      95.020000     87.660000
#
#        peak_value_opt  rms_10_25khz  rms_1_10khz  rotor_balance_status  \
# count      715.000000         715.0   715.000000            715.000000
# mean        91.090140          98.0    96.956545             84.863469
# std          0.682508           0.0     0.118365              2.357457
# min         88.150000          98.0    96.720000             80.030000
# 25%         90.665000          98.0    96.870000             83.245000
# 50%         91.140000          98.0    96.930000             84.920000
# 75%         91.530000          98.0    97.020000             86.775000
# max         93.410000          98.0    97.420000             94.770000
#
#        rubbing_condition  velocity_rms
# count         715.000000    715.000000
# mean           97.705594     68.410434
# std             0.650879      2.600310
# min            94.610000     62.650000
# 25%            97.410000     66.710000
# 50%            97.840000     68.200000
# 75%            98.110000     69.790000
# max            98.950000     77.250000
#
# [8 rows x 32 columns]
#
# Missing Values:
# datetime                               0
# High-Frequency Acceleration_mean       0
# High-Frequency Acceleration_min        0
# High-Frequency Acceleration_max        0
# High-Frequency Acceleration_median     0
# High-Frequency Acceleration_std        0
# Low-Frequency Acceleration Z_mean      0
# Low-Frequency Acceleration Z_min       0
# Low-Frequency Acceleration Z_max       0
# Low-Frequency Acceleration Z_median    0
# Low-Frequency Acceleration Z_std       0
# Temperature_mean                       0
# Temperature_min                        0
# Temperature_max                        0
# Temperature_median                     0
# Temperature_std                        0
# Vibration Velocity Z_mean              0
# Vibration Velocity Z_min               0
# Vibration Velocity Z_max               0
# Vibration Velocity Z_median            0
# Vibration Velocity Z_std               0
# location                               0
# Device                                 0
# alignment_status                       0
# bearing_lubrication                    0
# crest_factor                           0
# electromagnetic_status                 0
# fit_condition                          0
# kurtosis_opt                           0
# peak_value_opt                         0
# rms_10_25khz                           0
# rms_1_10khz                            0
# rotor_balance_status                   0
# rubbing_condition                      0
# velocity_rms                           0
# dtype: int64

# %%
plot_feature_distributions(df, INPUT_FEATURES, f"{get_device_name(DEVICE)} - FEATURE HISTOGRAM DISTRIBUTION", save_path=SAVE_PATH)

# %%
plot_feature_distributions(df, INPUT_FEATURES, f"{get_device_name(DEVICE)} - FEATURE HISTOGRAM DISTRIBUTION (OUTLIERS REMOVED)", remove_outliers=True, save_path=SAVE_PATH)

# %%
plot_feature_correlation_heatmap(df, INPUT_FEATURES, f"{get_device_name(DEVICE)} - FEATURE CORRELATION HEATMAP", save_path=SAVE_PATH)

# %%
plot_feature_boxplots(df, INPUT_FEATURES, f"{get_device_name(DEVICE)} - FEATURE BOXPLOTS DISTRIBUTIONS", save_path=SAVE_PATH)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plot_feature_boxplots(df, INPUT_FEATURES, f"{get_device_name(DEVICE)} - FEATURE BOXPLOTS DISTRIBUTIONS", save_path=SAVE_PATH)
#
# File ~/Desktop/capstone/capstone/model/utils/eda_utils.py:146, in plot_feature_boxplots(df, features, title, remove_outliers, save_path)
#     143 plt.suptitle(title, fontsize=16)
#     145 for i, feature in enumerate(features):
# --> 146     sns.boxplot(data=df, x="location", y=feature, ax=axes[i])
#     147     axes[i].set_title(feature)
#     148     axes[i].set_xlabel("Location")
#
# IndexError: index 4 is out of bounds for axis 0 with size 4

# %%
plot_feature_boxplots(df, INPUT_FEATURES, f"{get_device_name(DEVICE)} - FEATURE BOXPLOTS DISTRIBUTIONS (OUTLIERS REMOVED)", remove_outliers=True,  save_path=SAVE_PATH)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 plot_feature_boxplots(df, INPUT_FEATURES, f"{get_device_name(DEVICE)} - FEATURE BOXPLOTS DISTRIBUTIONS (OUTLIERS REMOVED)", remove_outliers=True,  save_path=SAVE_PATH)
#
# File ~/Desktop/capstone/capstone/model/utils/eda_utils.py:146, in plot_feature_boxplots(df, features, title, remove_outliers, save_path)
#     143 plt.suptitle(title, fontsize=16)
#     145 for i, feature in enumerate(features):
# --> 146     sns.boxplot(data=df, x="location", y=feature, ax=axes[i])
#     147     axes[i].set_title(feature)
#     148     axes[i].set_xlabel("Location")
#
# IndexError: index 4 is out of bounds for axis 0 with size 4

# %%
plot_target_distributions(df, TARGET_FEATURES, f"{get_device_name(DEVICE)} - TARGET HISTOGRAM DISTRIBUTIONS",save_path=SAVE_PATH)

# %%
plot_target_boxplots(df, TARGET_FEATURES, f"{get_device_name(DEVICE)} - TARGET BOXPLOTS DISTRIBUTIIONS", save_path=SAVE_PATH)

# %%
plot_input_target_correlation_heatmap(df, INPUT_FEATURES, TARGET_FEATURES,
                                      title=f"{get_device_name(DEVICE)} - FEATURE VS TARGET CORRELATION HEATMAP", save_path=SAVE_PATH)

# %%
# INPUT_FEATURES = append_suffix(INPUT_FEATURES, "mean")
plot_input_target_pairplot(df, INPUT_FEATURES, TARGET_FEATURES,
                                      title=f"{get_device_name(DEVICE)} - FEATURE VS TARGET PAIRPLOT", save_path=SAVE_PATH)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 2
#       1 # INPUT_FEATURES = append_suffix(INPUT_FEATURES, "mean")
# ----> 2 plot_input_target_pairplot(df, INPUT_FEATURES, TARGET_FEATURES,
#       3                                       title=f"{get_device_name(DEVICE)} - FEATURE VS TARGET PAIRPLOT", save_path=SAVE_PATH)
#
# File ~/Desktop/capstone/capstone/model/utils/eda_utils.py:271, in plot_input_target_pairplot(df, input_features, target_features, title, save_path)
#     257 """
#     258 Plot a pairplot showing the relationship between input features and target features.
#     259
#    (...)    268     None
#     269 """
#     270 if not set(input_features + target_features).issubset(df.columns):
# --> 271     raise ValueError("Some input or target features are missing from the DataFrame.")
#     273 sns.pairplot(df, x_vars=input_features, y_vars=target_features, height=3.5)
#     274 plt.suptitle(title, y=1.02, fontsize=16)
#
# ValueError: Some input or target features are missing from the DataFrame.
