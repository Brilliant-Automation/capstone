# %%
import sys
import os
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(PROJECT_ROOT)

from model.utils import (
    load_and_clean_data,
    show_summary,
    plot_feature_distributions,
    plot_feature_correlation_heatmap,
    plot_input_target_correlation_heatmap,
    plot_input_target_pairplot,
    plot_feature_boxplots,
    plot_target_distributions,
    plot_target_boxplots,
    get_device_name,
    append_suffix,
    DEVICE_TARGET_FEATURES,
    INPUT_FEATURES
)
INPUT_FEATURES = append_suffix(INPUT_FEATURES, "mean")

DEVICE = "high_temp_fan"
TARGET_FEATURES = DEVICE_TARGET_FEATURES[DEVICE]
DATA_DIR = "../Data/process/1#High-Temp Fan_merged.csv"
SAVE_PATH = f"../docs/images/{DEVICE}_plots/"

# %%
INPUT_FEATURES = [
    'High-Frequency Acceleration_mean', 'High-Frequency Acceleration_min',
    'High-Frequency Acceleration_max', 'High-Frequency Acceleration_median',
    'High-Frequency Acceleration_std', 'Low-Frequency Acceleration Z_mean',
    'Low-Frequency Acceleration Z_min', 'Low-Frequency Acceleration Z_max',
    'Low-Frequency Acceleration Z_median', 'Low-Frequency Acceleration Z_std',
    'Temperature_mean', 'Temperature_min', 'Temperature_max', 'Temperature_median',
    'Temperature_std', 'Vibration Velocity Z_mean', 'Vibration Velocity Z_min',
    'Vibration Velocity Z_max', 'Vibration Velocity Z_median', 'Vibration Velocity Z_std'
]

# %%
df = load_and_clean_data(DATA_DIR)

# %%
show_summary(df)
# Out:
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 712 entries, 0 to 712
# Data columns (total 34 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   datetime                             712 non-null    object
#  1   High-Frequency Acceleration_mean     712 non-null    float64
#  2   High-Frequency Acceleration_min      712 non-null    float64
#  3   High-Frequency Acceleration_max      712 non-null    float64
#  4   High-Frequency Acceleration_median   712 non-null    float64
#  5   High-Frequency Acceleration_std      712 non-null    float64
#  6   Low-Frequency Acceleration Z_mean    712 non-null    float64
#  7   Low-Frequency Acceleration Z_min     712 non-null    float64
#  8   Low-Frequency Acceleration Z_max     712 non-null    float64
#  9   Low-Frequency Acceleration Z_median  712 non-null    float64
#  10  Low-Frequency Acceleration Z_std     712 non-null    float64
#  11  Temperature_mean                     712 non-null    float64
#  12  Temperature_min                      712 non-null    float64
#  13  Temperature_max                      712 non-null    float64
#  14  Temperature_median                   712 non-null    float64
#  15  Temperature_std                      712 non-null    float64
#  16  Vibration Velocity Z_mean            712 non-null    float64
#  17  Vibration Velocity Z_min             712 non-null    float64
#  18  Vibration Velocity Z_max             712 non-null    float64
#  19  Vibration Velocity Z_median          712 non-null    float64
#  20  Vibration Velocity Z_std             712 non-null    float64
#  21  location                             712 non-null    object
#  22  Device                               712 non-null    object
#  23  alignment_status                     712 non-null    float64
#  24  bearing_lubrication                  712 non-null    float64
#  25  crest_factor                         712 non-null    float64
#  26  electromagnetic_status               712 non-null    float64
#  27  fit_condition                        712 non-null    float64
#  28  kurtosis_opt                         712 non-null    float64
#  29  rms_10_25khz                         712 non-null    float64
#  30  rms_1_10khz                          712 non-null    float64
#  31  rotor_balance_status                 712 non-null    float64
#  32  rubbing_condition                    712 non-null    float64
#  33  velocity_rms                         712 non-null    float64
# dtypes: float64(31), object(3)
# memory usage: 194.7+ KB
# None
#
# Statistical Summary:
#        High-Frequency Acceleration_mean  High-Frequency Acceleration_min  \
# count                        712.000000                       712.000000
# mean                           4.480788                         1.502799
# std                            2.054366                         0.061922
# min                            2.194608                         1.329380
# 25%                            3.337667                         1.456280
# 50%                            3.812802                         1.495445
# 75%                            5.041978                         1.542590
# max                           13.634530                         1.770950
#
#        High-Frequency Acceleration_max  High-Frequency Acceleration_median  \
# count                       712.000000                          712.000000
# mean                         13.633376                            3.003503
# std                          12.372469                            1.091411
# min                           3.417820                            1.899685
# 25%                           7.937758                            2.268700
# 50%                           8.821975                            2.443370
# 75%                          10.815670                            3.478539
# max                          51.574950                            5.863605
#
#        High-Frequency Acceleration_std  Low-Frequency Acceleration Z_mean  \
# count                       712.000000                         712.000000
# mean                          3.792333                           0.653968
# std                           3.279606                           0.052041
# min                           0.676851                           0.564003
# 25%                           2.337858                           0.606917
# 50%                           2.777623                           0.655020
# 75%                           3.455078                           0.695117
# max                          18.207582                           0.765084
#
#        Low-Frequency Acceleration Z_min  Low-Frequency Acceleration Z_max  \
# count                        712.000000                        712.000000
# mean                           0.459225                          1.016338
# std                            0.028492                          0.217023
# min                            0.379370                          0.836380
# 25%                            0.437780                          0.920120
# 50%                            0.460545                          0.968520
# 75%                            0.481230                          1.015350
# max                            0.525760                          2.717720
#
#        Low-Frequency Acceleration Z_median  Low-Frequency Acceleration Z_std  \
# count                           712.000000                        712.000000
# mean                              0.628848                          0.147803
# std                               0.083601                          0.022487
# min                               0.490315                          0.106698
# 25%                               0.542994                          0.133940
# 50%                               0.629338                          0.145414
# 75%                               0.700214                          0.158542
# max                               0.788925                          0.277496
#
#        ...  bearing_lubrication  crest_factor  electromagnetic_status  \
# count  ...           712.000000    712.000000              712.000000
# mean   ...            91.521320     86.055154               97.809284
# std    ...             3.090251      4.343957                0.661989
# min    ...            77.620000     71.710000               93.350000
# 25%    ...            89.917500     84.692500               98.000000
# 50%    ...            92.690000     87.780000               98.000000
# 75%    ...            93.542500     89.070000               98.000000
# max    ...            96.190000     90.530000               98.000000
#
#        fit_condition  kurtosis_opt  rms_10_25khz  rms_1_10khz  \
# count     712.000000    712.000000    712.000000   712.000000
# mean       97.384143     86.621096     94.224480    89.889284
# std         0.770586      1.058257      3.278656     6.142819
# min        95.030000     81.320000     77.640000    62.890000
# 25%        96.955000     86.810000     93.880000    89.360000
# 50%        97.725000     87.000000     95.310000    91.270000
# 75%        98.000000     87.150000     95.930000    92.832500
# max        98.000000     87.470000     96.990000    97.310000
#
#        rotor_balance_status  rubbing_condition  velocity_rms
# count            712.000000         712.000000    712.000000
# mean              97.200506          96.322121     93.761096
# std                0.698325           3.258068      1.962314
# min               89.020000          80.850000     78.710000
# 25%               97.180000          96.117500     92.250000
# 50%               97.360000          97.235000     94.835000
# 75%               97.500000          97.942500     95.290000
# max               97.840000          99.390000     95.750000
#
# [8 rows x 31 columns]
#
# Missing Values:
# datetime                               0
# High-Frequency Acceleration_mean       0
# High-Frequency Acceleration_min        0
# High-Frequency Acceleration_max        0
# High-Frequency Acceleration_median     0
# High-Frequency Acceleration_std        0
# Low-Frequency Acceleration Z_mean      0
# Low-Frequency Acceleration Z_min       0
# Low-Frequency Acceleration Z_max       0
# Low-Frequency Acceleration Z_median    0
# Low-Frequency Acceleration Z_std       0
# Temperature_mean                       0
# Temperature_min                        0
# Temperature_max                        0
# Temperature_median                     0
# Temperature_std                        0
# Vibration Velocity Z_mean              0
# Vibration Velocity Z_min               0
# Vibration Velocity Z_max               0
# Vibration Velocity Z_median            0
# Vibration Velocity Z_std               0
# location                               0
# Device                                 0
# alignment_status                       0
# bearing_lubrication                    0
# crest_factor                           0
# electromagnetic_status                 0
# fit_condition                          0
# kurtosis_opt                           0
# rms_10_25khz                           0
# rms_1_10khz                            0
# rotor_balance_status                   0
# rubbing_condition                      0
# velocity_rms                           0
# dtype: int64

# %%
plot_feature_distributions(df, INPUT_FEATURES , f"{get_device_name(DEVICE)} - FEATURE HISTOGRAM DISTRIBUTION", save_path=SAVE_PATH)

# %%
# plot_feature_distributions(df, INPUT_FEATURES, f"{get_device_name(DEVICE)} - FEATURE HISTOGRAM DISTRIBUTION (OUTLIERS REMOVED)", remove_outliers=True, save_path=SAVE_PATH)

# %%
plot_feature_correlation_heatmap(df, INPUT_FEATURES, f"{get_device_name(DEVICE)} - FEATURE CORRELATION HEATMAP", save_path=SAVE_PATH)

# %%
plot_feature_boxplots(df, INPUT_FEATURES, f"{get_device_name(DEVICE)} - FEATURE BOXPLOTS DISTRIBUTIONS", save_path=SAVE_PATH)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 plot_feature_boxplots(df, INPUT_FEATURES, f"{get_device_name(DEVICE)} - FEATURE BOXPLOTS DISTRIBUTIONS", save_path=SAVE_PATH)
#
# File ~/Desktop/capstone/capstone/model/utils/eda_utils.py:146, in plot_feature_boxplots(df, features, title, remove_outliers, save_path)
#     143 plt.suptitle(title, fontsize=16)
#     145 for i, feature in enumerate(features):
# --> 146     sns.boxplot(data=df, x="location", y=feature, ax=axes[i])
#     147     axes[i].set_title(feature)
#     148     axes[i].set_xlabel("Location")
#
# IndexError: index 4 is out of bounds for axis 0 with size 4

# %%
plot_feature_boxplots(df, INPUT_FEATURES, f"{get_device_name(DEVICE)} - FEATURE BOXPLOTS DISTRIBUTIONS (OUTLIERS REMOVED)", remove_outliers=True,  save_path=SAVE_PATH)

# %%
plot_target_distributions(df, TARGET_FEATURES, f"{get_device_name(DEVICE)} - TARGET HISTOGRAM DISTRIBUTIONS",save_path=SAVE_PATH)

# %%
plot_target_boxplots(df, TARGET_FEATURES, f"{get_device_name(DEVICE)} - TARGET BOXPLOTS DISTRIBUTIIONS", save_path=SAVE_PATH)

# %%
plot_input_target_correlation_heatmap(df, INPUT_FEATURES, TARGET_FEATURES,
                                      title=f"{get_device_name(DEVICE)} - FEATURE VS TARGET CORRELATION HEATMAP", save_path=SAVE_PATH)

# %%
plot_input_target_pairplot(df, INPUT_FEATURES, TARGET_FEATURES,
                                      title=f"{get_device_name(DEVICE)} - FEATURE VS TARGET PAIRPLOT", save_path=SAVE_PATH)
